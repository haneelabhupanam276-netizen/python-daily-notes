# %% [markdown]
# <a href="https://colab.research.google.com/github/haneelabhupanam276-netizen/python-daily-notes/blob/main/haneela_bhupanam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Write a Python program that takes the length and width of a rectangle from the user and prints its area.

# %%
l = int(input("enter the length of rectangle :"))
w = int(input("enter the wifdth of rectangle :"))
area =1*w
print("the area of rectangle is :",area)
# Out:
# enter the length of rectangle :2
# enter the wifdth of rectangle :5
# the area of rectangle is : 5

# %% [markdown]
# 2. Write a program that asks the user for the side of a square and prints its perimeter.

# %%
s =float(input("enter the side of a sqaure:"))
perimeter = 4 * s
print("the perimeter of square is :",perimeter)
# Out:
# enter the side of a sqaure:6
# the perimeter of square is : 24.0

# %% [markdown]
# 3. Take the base and height of a triangle as input and print its area.

# %%
b = float(input("enter the base of traingle :"))
h = float(input("enter the height of traingle :"))
area = 0.5 *b *h
print("The area of traingle is :",area)
# Out:
# enter the base of traingle :5
# enter the height of traingle :6
# The area of traingle is : 15.0

# %% [markdown]
# 4. Write a program that asks the user for the radius of a circle and prints its circumference. (Use 3.14 for π).

# %%
r =float(input("enter the radius of circle :"))
circumference = 2*3.142*r
print("the circumference of circle is :",circumference)
# Out:
# enter the radius of circle :3
# the circumference of circle is : 18.852

# %% [markdown]
# 5. Take Principal (P), Rate (R), and Time (T) as input from the user and print the Simple Interest.

# %%
p = float(input("enter the pricipal amount :"))
r = float(input("enter the rate of intrest :"))
t = float(input("enter the time :"))
simple_interest = (p*r*t)/100
print("the simple intrest is :",simple_interest)
# Out:
# enter the pricipal amount :3
# enter the rate of intrest :4
# enter the time :5
# the simple intrest is : 0.6
